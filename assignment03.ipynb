# %% [markdown]
# # Assignment #3

# %% [markdown]
# ## Task 1
#
# Develop an algorithm that would sort numbers from least to greatest. Specifically, given an unsorted set of N decimal values, your function should sort them to give an answer of the sorted data. For example, if you get the list of numbers [2.1, 0, 5.7, -1.2, 3, 1.5] as input, your function should return [-1.2, 0, 1.5, 2.1, 3, 5.7].
#
# You are **NOT** allowed to use sort function available in any package!

# %%
def sort(input_list):
    ss = input_list[0]
    bs = 0
    l1 = []
    l2 = []
    ilc = input_list
    for i in range(len(input_list)):
        for item in ilc:
            if(ss>item):
                ss = item
            if(item>bs):
                bs = item
        l1.append(ss)
        l2.append(bs)
        if(ss in ilc):
            ilc.remove(ss)
        if(bs in ilc):
            ilc.remove(bs)
        if(ilc==[]):
            break
        ss = ilc[0]
        bs = 0
    output_list = l1 + l2[::-1]
    return output_list
print(sort([2.1, 0, 5.7, -1.2, 3, 1.5] ))
# Out:
# [-1.2, 0, 1.5, 2.1, 3, 5.7]

# %% [markdown]
# Test you function with the given list:

# %%
import numpy as np

# %%
np.random.seed(1)
l= np.random.randn(100)*100
l = list(l)
print(sort(l))
# Out:
# [-230.15386968802827, -206.0140709497654, -202.2201215824003, -144.41138054295894, -139.64963354881377, -114.25181980221402, -111.73103486352778, -110.06191772129212, -109.98912673140309, -107.29686221561705, -93.57694342590688, -88.76289640848363, -87.78584179213718, -84.52056414987196, -76.12069008951028, -75.43979409966528, -74.71582937508376, -69.16607517253091, -68.71727001195994, -68.3727859174333, -67.12461308368191, -67.06622862890306, -63.87304074542224, -63.69956465693534, -62.00008439481293, -61.175641365007536, -52.81717522634557, -50.44658629464512, -39.67535268559774, -38.40543546684157, -37.52849500901142, -35.22498464935187, -34.93427224128775, -34.38536755710756, -32.24172040135075, -30.620401262837184, -29.809283510271566, -26.78880796260159, -24.93703754774101, -22.232814261035927, -20.88942333747781, -20.075806892999744, -19.183555236161492, -17.242820755043574, -12.289022551864818, -7.557171302105573, -1.266459891890136, 4.221374671559283, 4.3596856834246935, 5.080775477602897, 7.734006834855942, 11.900864580745882, 12.015895248162915, 12.182127099143694, 16.003706944783048, 18.515641748394383, 18.65613909882843, 19.0915484667466, 19.829972012676976, 23.009473536438342, 23.441569781709216, 28.558732525425878, 30.017031995582748, 31.563494724160524, 31.903909605709856, 37.756378632091945, 41.00516472082563, 42.34943540641129, 48.851814653749706, 50.24943389018682, 51.29298204180088, 53.0355466738186, 58.28152137158222, 58.66231911821976, 61.72031097074192, 69.80320340722189, 74.20441605773355, 76.20111803120247, 82.79746426072462, 83.89834138745049, 86.54076293246786, 87.61689211162249, 88.5141164270728, 90.08559492644117, 90.15907205927955, 93.11020813035573, 112.94839079119197, 113.1629387451427, 113.37694423354374, 114.47237098396141, 119.8917879901507, 125.28681552332878, 146.2107937044974, 151.98168164221988, 162.43453636632415, 165.98021771098706, 169.24546010277467, 174.481176421648, 210.02551364788422, 218.55754065331615]

# %% [markdown]
# You can compare your results with the results generated by following cell:

# %%
l_sorted= np.sort(l)
l_sorted
# Out:
# array([-230.15386969, -206.01407095, -202.22012158, -144.41138054,
#        -139.64963355, -114.2518198 , -111.73103486, -110.06191772,
#        -109.98912673, -107.29686222,  -93.57694343,  -88.76289641,
#         -87.78584179,  -84.52056415,  -76.12069009,  -75.4397941 ,
#         -74.71582938,  -69.16607517,  -68.71727001,  -68.37278592,
#         -67.12461308,  -67.06622863,  -63.87304075,  -63.69956466,
#         -62.00008439,  -61.17564137,  -52.81717523,  -50.44658629,
#         -39.67535269,  -38.40543547,  -37.52849501,  -35.22498465,
#         -34.93427224,  -34.38536756,  -32.2417204 ,  -30.62040126,
#         -29.80928351,  -26.78880796,  -24.93703755,  -22.23281426,
#         -20.88942334,  -20.07580689,  -19.18355524,  -17.24282076,
#         -12.28902255,   -7.5571713 ,   -1.26645989,    4.22137467,
#           4.35968568,    5.08077548,    7.73400683,   11.90086458,
#          12.01589525,   12.1821271 ,   16.00370694,   18.51564175,
#          18.6561391 ,   19.09154847,   19.82997201,   23.00947354,
#          23.44156978,   28.55873253,   30.017032  ,   31.56349472,
#          31.90390961,   37.75637863,   41.00516472,   42.34943541,
#          48.85181465,   50.24943389,   51.29298204,   53.03554667,
#          58.28152137,   58.66231912,   61.72031097,   69.80320341,
#          74.20441606,   76.20111803,   82.79746426,   83.89834139,
#          86.54076293,   87.61689211,   88.51411643,   90.08559493,
#          90.15907206,   93.11020813,  112.94839079,  113.16293875,
#         113.37694423,  114.47237098,  119.89178799,  125.28681552,
#         146.2107937 ,  151.98168164,  162.43453637,  165.98021771,
#         169.2454601 ,  174.48117642,  210.02551365,  218.55754065])

# %% [markdown]
# ## Task 2
#
# Write a function which gets a non-negative integer as input and prints a triangle with the height of given number. For example, given an input 3, the function should print:
#
#     *
#     **
#     ***
#
# **Hint**: read the documentation for [print](https://docs.python.org/3/library/functions.html#print) function. You can specify the *end* argument.

# %%
def star(n):
    star = '*'
    for i in range(0,n):
        yield star
        star+='*'

# %% [markdown]
# Test your function with n = 7

# %%
for item in star(7):
    print(item)
# Out:
# *
# **
# ***
# ****
# *****
# ******
# *******

# %% [markdown]
# ## I have a question
# look at None.how to do not print this None.I know if i use return i will not see this None but if i use return the function will break.
# How can i print the output without None in end of it.

# %% [markdown]
# ## Task 3
#
# We can define a rectangle with 4 numbers being x, y, width and height. For example, look at the rectangle below:
#
# ![](img/rectangle.png)
#
#
# We can define this rectangle by x = 2, y = 1, width = 3 , height = 5
#
#
# Write a function which gets a rectangle and a drawing area size and draws the rectangle. You only need to draw the the first quadrant of coordinate plane, that is, you function should only accept non-negative x and y. For example, given rect = (2, 1, 3, 5) and size = (10, 10) , your function should print:
#
#     ----------
#     ----------
#     ----------
#     ----------
#     --***-----
#     --***-----
#     --***-----
#     --***-----
#     --***-----
#     ----------
#
# Your function should check the followings and return an appropriate error in each case:
# - Whether the rectangle fits into the given size or not. For example, given rect = (2, 1, 3, 5) and size = (5, 3), the function should print an error message saying the rectangle does not fit in the given size.
# - Whether the numbers given in rectangle or in size are valid. For example, rect = (-2, 1, 3, 5) is not valid as we only draw in first quadrant. Or rect = (2, 1, -2, 5) is not valid as the width cannot be negative. The same goes for the size.

# %%
def coordinate(rect,size):
    line = 1
    string = ''
    my_list = []
    a = size[0]-rect[1]
    b = a - rect[-1]
    for k in range(b + 1, a + 1):
        my_list.append(k)
    for i in range(0,size[0]):
        if(rect[0]<=0 or rect[2]<=0):
            print('look at your rect please.')
            break
        if(rect[2]>size[0] or rect[3]>size[1]):
            print('look at your size please.')
            break
        if(line in my_list):
            string+='-'*rect[0]
            string+='*'*rect[2]
            result = size[1]
            for char in string:
                result -= 1
            string+='-'*result
            yield string
            string = ''
            line+=1
        else:
            string+='-'*size[0]
            yield (string)
            string = ''
            line+=1 


for item in coordinate((2,1,3,5),(10,10)):
    print(item)
# Out:
# ----------
# ----------
# ----------
# ----------
# --***-----
# --***-----
# --***-----
# --***-----
# --***-----
# ----------

# %% [markdown]
# Test you function:

# %%
rects = [(5, 3, 7, 4), (2, 1, -3, 2), (0, 5, 3, 0)]
sizes = [(15, 15), (5, 5), (-1, 3)]
for rect in rects:
    for size in sizes:
        for item in coordinate(rect,size):
            print(item)
# Out:
# ---------------
# ---------------
# ---------------
# ---------------
# ---------------
# ---------------
# ---------------
# ---------------
# -----*******---
# -----*******---
# -----*******---
# -----*******---
# ---------------
# ---------------
# ---------------
# look at your size please.
# look at your rect please.
# look at your rect please.
# look at your rect please.
# look at your rect please.

# %% [markdown]
# ## Task 4
#
# Write a function that gets two rectangles and a size as input and draws them such that:
# - for the empty area prints 0
# - for the area only in rectangle 1 prints 1
# - for rectangle 2 prints 2
# - for the area in both rectangle 1 and 2 prints 3
#
# For example, given rect1 = (2, 1, 3, 5) and rect2 = (3, 4, 4, 4) and size = (10, 10), your function should print:
#
#     0000000000
#     0000000000
#     0002222000
#     0002222000
#     0013322000
#     0013322000
#     0011100000
#     0011100000
#     0011100000
#     0000000000

# %%
def one_two_three(rect1,rect2,size):
    try:
        a = ''
        b = ''
        index = 0
        string = ''
        count = 0
        
        for item in coordinate(rect1,size):
            
            for char in item:
                a+=char
        for items in coordinate(rect2,size):
            for chars in items:
                b+=chars
        for i in range(size[0]*size[0]):
            if(a[index]=='-'):
                if(b[index]=='-'):
                    string+='0'
                    index+=1
                elif(b[index]=='*'):
                    string+='2'
                    index+=1
            elif(a[index]=='*'):
                if(b[index]=='-'):
                    string+='1'
                    index+=1
                elif(b[index]=='*'):
                    string+='3'
                    index+=1
            if(len(string)==size[1]):
                count+=1
                yield string
                string = ''
    except IndexError:
        pass

# %% [markdown]
# Test your function:

# %%
rects = [(2, 1, 7, 5), (4, 2, 3, 2), (1, 8, 9, 2), (7, 3, 4, 5), (11, 2, 1, 7), (9, 4, 3, 3)]
size = (15, 15)
for rect in rects:
    for item in one_two_three(rects[0], rect, size):
        print(item)
# Out:
# 000000000000000
# 000000000000000
# 000000000000000
# 000000000000000
# 000000000000000
# 000000000000000
# 000000000000000
# 000000000000000
# 000000000000000
# 003333333000000
# 003333333000000
# 003333333000000
# 003333333000000
# 003333333000000
# 000000000000000
# 000000000000000
# 000000000000000
# 000000000000000
# 000000000000000
# 000000000000000
# 000000000000000
# 000000000000000
# 000000000000000
# 000000000000000
# 001111111000000
# 001111111000000
# 001133311000000
# 001133311000000
# 001111111000000
# 000000000000000
# 000000000000000
# 000000000000000
# 000000000000000
# 000000000000000
# 000000000000000
# 022222222200000
# 022222222200000
# 000000000000000
# 000000000000000
# 001111111000000
# 001111111000000
# 001111111000000
# 001111111000000
# 001111111000000
# 000000000000000
# 000000000000000
# 000000000000000
# 000000000000000
# 000000000000000
# 000000000000000
# 000000000000000
# 000000000000000
# 000000022220000
# 000000022220000
# 001111133220000
# 001111133220000
# 001111133220000
# 001111111000000
# 001111111000000
# 000000000000000
# 000000000000000
# 000000000000000
# 000000000000000
# 000000000000000
# 000000000000000
# 000000000000000
# 000000000002000
# 000000000002000
# 000000000002000
# 001111111002000
# 001111111002000
# 001111111002000
# 001111111002000
# 001111111000000
# 000000000000000
# 000000000000000
# 000000000000000
# 000000000000000
# 000000000000000
# 000000000000000
# 000000000000000
# 000000000000000
# 000000000000000
# 000000000222000
# 001111111222000
# 001111111222000
# 001111111000000
# 001111111000000
# 001111111000000
# 000000000000000
